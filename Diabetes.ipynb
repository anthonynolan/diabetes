# %% [markdown]
# https://archive.ics.uci.edu/ml/datasets/Diabetes+130-US+hospitals+for+years+1999-2008

# %%
import pandas as pd
import numpy as np
dat = pd.read_csv('diabetes_data/diabetic_data.csv')
dat.set_index('encounter_id', inplace=True, verify_integrity=True)
dat.sort_values(['encounter_id'], inplace=True)
dat.reset_index(inplace=True)

# %%
display(dat.tail())
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
# ...

# %%
multiple_visit_patients = dat.groupby('patient_nbr').size().sort_values(ascending=False)

# %%
import matplotlib.pyplot as plt
multiple_visit_patients[multiple_visit_patients>1].plot(kind='hist', bins=20)
plt.show()

# %%
dat.groupby('patient_nbr').count()[:5]
# Out:
#              race  gender  age  weight  admission_type_id  \
# patient_nbr
# 135             2       2    2       2                  2
# 378             1       1    1       1                  1
# 729             1       1    1       1                  1
# 774             1       1    1       1                  1
# 927             1       1    1       1                  1
#
#              discharge_disposition_id  admission_source_id  time_in_hospital  \
# patient_nbr
# 135                                 2                    2                 2
# 378                                 1                    1                 1
# 729                                 1                    1                 1
# 774                                 1                    1                 1
# 927                                 1                    1                 1
#
#              payer_code  medical_specialty     ...      citoglipton  insulin  \
# ...

# %%
dat['patient_nbr'].value_counts().reset_index()[:10]
# Out:
#       index  patient_nbr
# 0  88785891           40
# 1  43140906           28
# 2  23199021           23
# 3   1660293           23
# 4  88227540           23
# 5  23643405           22
# 6  84428613           22
# 7  92709351           21
# 8  23398488           20
# 9  90609804           20

# %%
dat.race.value_counts()
# Out:
# Caucasian          76099
# AfricanAmerican    19210
# ?                   2273
# Hispanic            2037
# Other               1506
# Asian                641
# Name: race, dtype: int64

# %%
dat.gender.value_counts()
# Out:
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: gender, dtype: int64

# %%
plt.figure(figsize=(14,6))
plt.hist(dat.index)
# Out:
# (array([10493., 16574., 16064., 20683., 10720.,  9958.,  7039.,  3438.,
#          3346.,  3451.]),
#  array([1.25220000e+04, 4.43979920e+07, 8.87834620e+07, 1.33168932e+08,
#         1.77554402e+08, 2.21939872e+08, 2.66325342e+08, 3.10710812e+08,
#         3.55096282e+08, 3.99481752e+08, 4.43867222e+08]),
#  <a list of 10 Patch objects>)

# %%
dat.head()
# Out:
#    encounter_id  patient_nbr             race  gender       age weight  \
# 0         12522     48330783        Caucasian  Female   [80-90)      ?
# 1         15738     63555939        Caucasian  Female  [90-100)      ?
# 2         16680     42519267        Caucasian    Male   [40-50)      ?
# 3         28236     89869032  AfricanAmerican  Female   [40-50)      ?
# 4         35754     82637451        Caucasian    Male   [50-60)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  2                         1                    4
# 1                  3                         3                    4
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  2                         1                    2
#
#    time_in_hospital    ...     citoglipton insulin  glyburide-metformin  \
# ...

# %%
lower_limit = np.min(dat.encounter_id.values)
ticks = np.linspace(np.min(dat.encounter_id.values), np.max(dat.encounter_id.values), num=10)

if 'encounter_id' not in dat.columns:
    dat.reset_index(inplace=True)

for upper_limit in ticks[1:]:
    
    temp_dat = dat[(dat['encounter_id']<upper_limit )& (dat['encounter_id']>lower_limit)]
    lower_limit = upper_limit
    
    age_counts = temp_dat.age.value_counts().reset_index().sort_values('index')
    age_counts.columns = ['age', 'count']
    plt.figure()
    plt.title('upper limit {:,.0f}'.format(upper_limit))
    plt.barh(y = age_counts['age'], width = age_counts['count'])

# %%
('{:,.0f}'.format(23000.444))
# Out:
# '23,000'

# %%
counts, bin_edges = np.histogram(dat.index, bins = 10)

# %%
bin_edges
# Out:
# array([1.25220000e+04, 4.43979920e+07, 8.87834620e+07, 1.33168932e+08,
#        1.77554402e+08, 2.21939872e+08, 2.66325342e+08, 3.10710812e+08,
#        3.55096282e+08, 3.99481752e+08, 4.43867222e+08])

# %%
plt.hist(dat.index, bins=20)
# Out:
# (array([ 3669.,  6824.,  7890.,  8684.,  8907.,  7157.,  9401., 11282.,
#          6127.,  4593.,  4953.,  5005.,  4828.,  2211.,  1702.,  1736.,
#          1604.,  1742.,  1802.,  1649.]),
#  array([1.25220000e+04, 2.22052570e+07, 4.43979920e+07, 6.65907270e+07,
#         8.87834620e+07, 1.10976197e+08, 1.33168932e+08, 1.55361667e+08,
#         1.77554402e+08, 1.99747137e+08, 2.21939872e+08, 2.44132607e+08,
#         2.66325342e+08, 2.88518077e+08, 3.10710812e+08, 3.32903547e+08,
#         3.55096282e+08, 3.77289017e+08, 3.99481752e+08, 4.21674487e+08,
#         4.43867222e+08]),
#  <a list of 20 Patch objects>)

# %%
np.max(dat.index.values), np.min(dat.index.values)
# Out:
# (443867222, 12522)

# %%
dat[(dat['patient_nbr']<44385470 )& (dat['patient_nbr']>0)]
# Out:
#               patient_nbr             race  gender      age weight  \
# encounter_id
# 16680            42519267        Caucasian    Male  [40-50)      ?
# 150006           22864131                ?  Female  [50-60)      ?
# 150048           21239181                ?    Male  [60-70)      ?
# 221634           21861756            Other  Female  [50-60)      ?
# 236316           40523301        Caucasian    Male  [80-90)      ?
# 250872           41606064        Caucasian    Male  [20-30)      ?
# 252822           18196434        Caucasian  Female  [80-90)      ?
# 293118            3327282        Caucasian  Female  [70-80)      ?
# 544194           34997814        Caucasian    Male  [60-70)      ?
# 550098           21820806  AfricanAmerican    Male  [50-60)      ?
# 590346           37746639  AfricanAmerican  Female  [40-50)      ?
# 623880           17928900        Caucasian  Female  [60-70)      ?
# 654918            3146373        Caucasian    Male  [40-50)      ?
# ...
